# %%
import pickle
embeddings = {}
with open('data/commonvoice_embeddings.pkl', 'rb') as file:
    embeddings = pickle.load(file)
import pandas as pd
df = pd.read_csv("./data/cv-corpus-21.0-delta-2025-03-14/en/validated.tsv", delimiter="\t")
value_dict = df[["path", "age"]]
value_dict = value_dict.set_index("path").rename_axis(None)
value_dict = value_dict.to_dict()["age"]
value_dict
# Out:
# {'common_voice_en_41923025.mp3': 'thirties',
#  'common_voice_en_42356358.mp3': 'teens',
#  'common_voice_en_42165090.mp3': nan,
#  'common_voice_en_41921729.mp3': 'nineties',
#  'common_voice_en_42528393.mp3': 'teens',
#  'common_voice_en_42006138.mp3': nan,
#  'common_voice_en_42555516.mp3': 'twenties',
#  'common_voice_en_41951792.mp3': 'thirties',
#  'common_voice_en_42446785.mp3': 'fifties',
#  'common_voice_en_41974998.mp3': 'twenties',
#  'common_voice_en_42020013.mp3': 'twenties',
#  'common_voice_en_42046273.mp3': 'twenties',
#  'common_voice_en_42458975.mp3': 'fourties',
#  'common_voice_en_42494012.mp3': 'thirties',
#  'common_voice_en_42435518.mp3': 'twenties',
#  'common_voice_en_41930868.mp3': nan,
#  'common_voice_en_42251480.mp3': 'sixties',
#  'common_voice_en_41923270.mp3': 'thirties',
#  'common_voice_en_42594358.mp3': 'thirties',
#  'common_voice_en_42141720.mp3': nan,
#  'common_voice_en_42498572.mp3': 'twenties',
#  'common_voice_en_42216083.mp3': 'fourties',
#  'common_voice_en_42466107.mp3': 'teens',
#  'common_voice_en_41970688.mp3': 'fifties',
#  'common_voice_en_42437221.mp3': nan,
#  'common_voice_en_42511436.mp3': 'sixties',
#  'common_voice_en_42511438.mp3': 'sixties',
#  'common_voice_en_41977227.mp3': 'thirties',
#  'common_voice_en_41977272.mp3': 'thirties',
#  'common_voice_en_41940683.mp3': 'twenties',
#  'common_voice_en_41940779.mp3': 'twenties',
#  'common_voice_en_42593468.mp3': 'twenties',
#  'common_voice_en_42593505.mp3': 'twenties',
#  'common_voice_en_41944826.mp3': 'twenties',
#  'common_voice_en_41944852.mp3': 'twenties',
#  'common_voice_en_41958320.mp3': 'twenties',
#  'common_voice_en_41958333.mp3': 'twenties',
#  'common_voice_en_41969910.mp3': 'fourties',
#  'common_voice_en_42182410.mp3': 'fourties',
#  'common_voice_en_42264420.mp3': 'fourties',
#  'common_voice_en_41918312.mp3': 'twenties',
#  'common_voice_en_41918321.mp3': 'twenties',
#  'common_voice_en_41918336.mp3': 'twenties',
#  'common_voice_en_41910645.mp3': 'twenties',
#  'common_voice_en_41910679.mp3': 'twenties',
#  'common_voice_en_42604282.mp3': 'twenties',
#  'common_voice_en_42510046.mp3': 'twenties',
#  'common_voice_en_42510071.mp3': 'twenties',
#  'common_voice_en_42510072.mp3': 'twenties',
#  'common_voice_en_41944462.mp3': 'thirties',
#  'common_voice_en_41944463.mp3': 'thirties',
#  'common_voice_en_41944465.mp3': 'thirties',
#  'common_voice_en_41923376.mp3': nan,
#  'common_voice_en_41923388.mp3': 'fourties',
#  'common_voice_en_41923390.mp3': 'fourties',
#  'common_voice_en_42095418.mp3': nan,
#  'common_voice_en_42095438.mp3': nan,
#  'common_voice_en_42356474.mp3': nan,
#  'common_voice_en_42356503.mp3': nan,
#  'common_voice_en_42527824.mp3': 'teens',
#  'common_voice_en_42527894.mp3': 'teens',
#  'common_voice_en_42527906.mp3': 'teens',
#  'common_voice_en_42527991.mp3': 'teens',
#  'common_voice_en_41921340.mp3': 'twenties',
#  'common_voice_en_41921355.mp3': 'twenties',
#  'common_voice_en_41921376.mp3': 'twenties',
#  'common_voice_en_41921406.mp3': 'twenties',
#  'common_voice_en_41921421.mp3': 'twenties',
#  'common_voice_en_41942247.mp3': 'twenties',
#  'common_voice_en_41942339.mp3': 'twenties',
#  'common_voice_en_41942375.mp3': 'twenties',
#  'common_voice_en_41942416.mp3': 'twenties',
#  'common_voice_en_41949226.mp3': 'twenties',
#  'common_voice_en_41984164.mp3': 'thirties',
#  'common_voice_en_41984166.mp3': 'thirties',
#  'common_voice_en_41984174.mp3': 'thirties',
#  'common_voice_en_41984175.mp3': 'thirties',
#  'common_voice_en_41984176.mp3': 'thirties',
#  'common_voice_en_41984186.mp3': 'thirties',
#  'common_voice_en_42479042.mp3': 'teens',
#  'common_voice_en_42479115.mp3': 'teens',
#  'common_voice_en_42479117.mp3': 'teens',
#  'common_voice_en_42479121.mp3': 'teens',
#  'common_voice_en_42498922.mp3': 'teens',
#  'common_voice_en_42498924.mp3': 'teens',
#  'common_voice_en_42498928.mp3': 'teens',
#  'common_voice_en_41971291.mp3': 'thirties',
#  'common_voice_en_41971323.mp3': 'thirties',
#  'common_voice_en_41971437.mp3': 'thirties',
#  'common_voice_en_41971694.mp3': 'thirties',
#  'common_voice_en_41971697.mp3': 'thirties',
#  'common_voice_en_41971750.mp3': 'thirties',
#  'common_voice_en_41971778.mp3': 'thirties',
#  'common_voice_en_41971860.mp3': 'thirties',
#  'common_voice_en_41971869.mp3': 'thirties',
#  'common_voice_en_42067967.mp3': 'sixties',
#  'common_voice_en_42123899.mp3': 'sixties',
#  'common_voice_en_42123909.mp3': 'sixties',
#  'common_voice_en_42123922.mp3': 'sixties',
#  'common_voice_en_42124330.mp3': 'sixties',
#  'common_voice_en_42145746.mp3': 'sixties',
#  'common_voice_en_42145770.mp3': 'sixties',
#  'common_voice_en_42145861.mp3': 'sixties',
#  'common_voice_en_42160853.mp3': 'sixties',
#  'common_voice_en_42358814.mp3': 'sixties',
#  'common_voice_en_42358911.mp3': 'sixties',
#  'common_voice_en_42358923.mp3': 'sixties',
#  'common_voice_en_42387424.mp3': 'sixties',
#  'common_voice_en_42387426.mp3': 'sixties',
#  'common_voice_en_42387486.mp3': 'sixties',
#  'common_voice_en_42387497.mp3': 'sixties',
#  'common_voice_en_42387498.mp3': 'sixties',
#  'common_voice_en_42387510.mp3': 'sixties',
#  'common_voice_en_42387511.mp3': 'sixties',
#  'common_voice_en_42387512.mp3': 'sixties',
#  'common_voice_en_42387523.mp3': 'sixties',
#  'common_voice_en_42387569.mp3': 'sixties',
#  'common_voice_en_42387598.mp3': 'sixties',
#  'common_voice_en_42387606.mp3': 'sixties',
#  'common_voice_en_42401091.mp3': 'sixties',
#  'common_voice_en_42401105.mp3': 'sixties',
#  'common_voice_en_42401155.mp3': 'sixties',
#  'common_voice_en_42428061.mp3': 'sixties',
#  'common_voice_en_42037987.mp3': 'thirties',
#  'common_voice_en_42037995.mp3': 'thirties',
#  'common_voice_en_42038020.mp3': 'thirties',
#  'common_voice_en_42041475.mp3': 'thirties',
#  'common_voice_en_42056178.mp3': 'thirties',
#  'common_voice_en_42056179.mp3': 'thirties',
#  'common_voice_en_42056186.mp3': 'thirties',
#  'common_voice_en_42056200.mp3': 'thirties',
#  'common_voice_en_42056243.mp3': 'thirties',
#  'common_voice_en_42056288.mp3': 'thirties',
#  'common_voice_en_42116383.mp3': 'thirties',
#  'common_voice_en_42164700.mp3': 'thirties',
#  'common_voice_en_42238557.mp3': 'thirties',
#  'common_voice_en_42238649.mp3': 'thirties',
#  'common_voice_en_42238716.mp3': 'thirties',
#  'common_voice_en_42238749.mp3': 'thirties',
#  'common_voice_en_42238820.mp3': 'thirties',
#  'common_voice_en_42312376.mp3': 'thirties',
#  'common_voice_en_42312550.mp3': 'thirties',
#  'common_voice_en_42312628.mp3': 'thirties',
#  'common_voice_en_42312652.mp3': 'thirties',
#  'common_voice_en_42312747.mp3': 'thirties',
#  'common_voice_en_42312771.mp3': 'thirties',
#  'common_voice_en_42356748.mp3': 'thirties',
#  'common_voice_en_42356785.mp3': 'thirties',
#  'common_voice_en_42357635.mp3': 'thirties',
#  'common_voice_en_42357648.mp3': 'thirties',
#  'common_voice_en_42505992.mp3': 'thirties',
#  'common_voice_en_42516884.mp3': 'thirties',
#  'common_voice_en_42516885.mp3': 'thirties',
#  'common_voice_en_42516896.mp3': 'thirties',
#  'common_voice_en_41917153.mp3': nan,
#  'common_voice_en_41917154.mp3': nan,
#  'common_voice_en_41917187.mp3': 'twenties',
#  'common_voice_en_41917197.mp3': 'twenties',
#  'common_voice_en_41917205.mp3': 'twenties',
#  'common_voice_en_41917228.mp3': 'twenties',
#  'common_voice_en_41917231.mp3': 'twenties',
#  'common_voice_en_41917242.mp3': 'twenties',
#  'common_voice_en_41917262.mp3': 'twenties',
#  'common_voice_en_41917265.mp3': 'twenties',
#  'common_voice_en_41917266.mp3': 'twenties',
#  'common_voice_en_41917319.mp3': 'twenties',
#  'common_voice_en_41917371.mp3': 'twenties',
#  'common_voice_en_41917375.mp3': 'twenties',
#  'common_voice_en_41917383.mp3': 'twenties',
#  'common_voice_en_41917385.mp3': 'twenties',
#  'common_voice_en_41917391.mp3': 'twenties',
#  'common_voice_en_41917392.mp3': 'twenties',
#  'common_voice_en_41917395.mp3': 'twenties',
#  'common_voice_en_41917459.mp3': 'twenties',
#  'common_voice_en_41917462.mp3': 'twenties',
#  'common_voice_en_41917466.mp3': 'twenties',
#  'common_voice_en_41917468.mp3': 'twenties',
#  'common_voice_en_41917472.mp3': 'twenties',
#  'common_voice_en_41917474.mp3': 'twenties',
#  'common_voice_en_41917478.mp3': 'twenties',
#  'common_voice_en_41917490.mp3': 'twenties',
#  'common_voice_en_41917493.mp3': 'twenties',
#  'common_voice_en_41917497.mp3': 'twenties',
#  'common_voice_en_41917515.mp3': 'twenties',
#  'common_voice_en_41917519.mp3': 'twenties',
#  'common_voice_en_41917524.mp3': 'twenties',
#  'common_voice_en_41917525.mp3': 'twenties',
#  'common_voice_en_41920788.mp3': 'twenties',
#  'common_voice_en_41920793.mp3': 'twenties',
#  'common_voice_en_41920806.mp3': 'twenties',
#  'common_voice_en_41920809.mp3': 'twenties',
#  'common_voice_en_41920828.mp3': 'twenties',
#  'common_voice_en_41920842.mp3': 'twenties',
#  'common_voice_en_41920850.mp3': 'twenties',
#  'common_voice_en_41920855.mp3': 'twenties',
#  'common_voice_en_41920860.mp3': 'twenties',
#  'common_voice_en_41920861.mp3': 'twenties',
#  'common_voice_en_41927938.mp3': 'twenties',
#  'common_voice_en_41927965.mp3': 'twenties',
#  'common_voice_en_41928094.mp3': 'twenties',
#  'common_voice_en_41928123.mp3': 'twenties',
#  'common_voice_en_41928171.mp3': 'twenties',
#  'common_voice_en_41928350.mp3': 'twenties',
#  'common_voice_en_41928371.mp3': 'twenties',
#  'common_voice_en_41928388.mp3': 'twenties',
#  'common_voice_en_41928403.mp3': 'twenties',
#  'common_voice_en_41928453.mp3': 'twenties',
#  'common_voice_en_41928476.mp3': 'twenties',
#  'common_voice_en_41928510.mp3': 'twenties',
#  'common_voice_en_41929016.mp3': 'twenties',
#  'common_voice_en_41929075.mp3': 'twenties',
#  'common_voice_en_41929143.mp3': 'twenties',
#  'common_voice_en_41929198.mp3': 'twenties',
#  'common_voice_en_41929216.mp3': 'twenties',
#  'common_voice_en_41929227.mp3': 'twenties',
#  'common_voice_en_41929248.mp3': 'twenties',
#  'common_voice_en_41929259.mp3': 'twenties',
#  'common_voice_en_41929263.mp3': 'twenties',
#  'common_voice_en_41929360.mp3': 'twenties',
#  'common_voice_en_41929456.mp3': 'twenties',
#  'common_voice_en_41929498.mp3': 'twenties',
#  'common_voice_en_41930644.mp3': 'twenties',
#  'common_voice_en_41930686.mp3': 'twenties',
#  'common_voice_en_41948210.mp3': 'twenties',
#  'common_voice_en_41948211.mp3': 'twenties',
#  'common_voice_en_41952158.mp3': 'twenties',
#  'common_voice_en_41952160.mp3': 'twenties',
#  'common_voice_en_41952161.mp3': 'twenties',
#  'common_voice_en_41952177.mp3': 'twenties',
#  'common_voice_en_41952209.mp3': 'twenties',
#  'common_voice_en_41952256.mp3': 'twenties',
#  'common_voice_en_41952276.mp3': 'twenties',
#  'common_voice_en_41952277.mp3': 'twenties',
#  'common_voice_en_41952302.mp3': 'twenties',
#  'common_voice_en_41961951.mp3': 'twenties',
#  'common_voice_en_41962016.mp3': 'twenties',
#  'common_voice_en_41962071.mp3': 'twenties',
#  'common_voice_en_41962321.mp3': 'twenties',
#  'common_voice_en_41962341.mp3': 'twenties',
#  'common_voice_en_41962478.mp3': 'twenties',
#  'common_voice_en_41962479.mp3': 'twenties',
#  'common_voice_en_42220389.mp3': 'twenties',
#  'common_voice_en_42220414.mp3': 'twenties',
#  'common_voice_en_42220435.mp3': 'twenties',
#  'common_voice_en_42220527.mp3': 'twenties',
#  'common_voice_en_42220889.mp3': 'twenties',
#  'common_voice_en_42221034.mp3': 'twenties',
#  'common_voice_en_42221077.mp3': 'twenties',
#  'common_voice_en_42221538.mp3': 'twenties'}

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report
import numpy as np
X = []
true_label = []
cluster_names = []
for key, val in embeddings.items():
    tl = value_dict[f"{key}.mp3"]
    if tl in ["twenties", "thirties", "sixties", "teens"]:
        X.append(val)
        true_label.append(tl)
        if tl not in cluster_names:
            cluster_names.append(tl)
X = np.array(X)

kmeans = KMeans(n_clusters=3, random_state=0, n_init="auto").fit(X)
cluster_labels = kmeans.labels_
print(classification_report(true_label, [cluster_names[l] for l in cluster_labels]))
# Out:
#               precision    recall  f1-score   support
#
#      sixties       0.04      0.13      0.07        31
#        teens       0.00      0.00      0.00        14
#     thirties       0.38      0.61      0.47        56
#     twenties       0.81      0.30      0.44       126
#
#     accuracy                           0.33       227
#    macro avg       0.31      0.26      0.24       227
# weighted avg       0.55      0.33      0.37       227
# /Users/rafkiep1/Desktop/AI_ethics_final/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/rafkiep1/Desktop/AI_ethics_final/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/rafkiep1/Desktop/AI_ethics_final/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
confusion_matrix = np.zeros((4, 4))
buckets = ["twenties", "thirties", "sixties", "teens"]

for idx, cl in enumerate(cluster_labels):
    confusion_matrix[buckets.index(true_label[idx])][cl] += 1
print(confusion_matrix)
purity_score = np.sum([np.max(r) for r in confusion_matrix])/len(cluster_labels)
print(purity_score)
# Out:
# [[38. 25. 63.  0.]
#  [ 5. 34. 17.  0.]
#  [ 1. 26.  4.  0.]
#  [ 3.  4.  7.  0.]]
# 0.5726872246696035
