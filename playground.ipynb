# %%
import pickle
embeddings = {}
with open('commonvoice_embeddings.pkl', 'rb') as file:
    embeddings = pickle.load(file)
embeddings
# Out:
# {'common_voice_en_41910645': tensor([[[ 0.0073,  0.0040,  0.0046,  ..., -0.1618,  0.0273, -0.0656],
#           [ 0.0019,  0.0040,  0.0057,  ..., -0.1453,  0.0353, -0.0690],
#           [ 0.0015,  0.0020,  0.0093,  ..., -0.1405,  0.0319, -0.0716],
#           ...,
#           [-0.0121,  0.0099, -0.0140,  ..., -0.1811,  0.0355, -0.0585],
#           [-0.0190, -0.0045,  0.0002,  ..., -0.1470,  0.0373, -0.0558],
#           [-0.0209, -0.0067,  0.0030,  ..., -0.1479,  0.0364, -0.0516]]]),
#  'common_voice_en_41910679': tensor([[[ 3.2895e-02,  3.1102e-02, -1.9933e-02,  ..., -8.3765e-02,
#             5.4732e-02,  8.2695e-02],
#           [ 1.9356e-02,  1.9732e-02, -1.1302e-02,  ..., -3.8397e-02,
#             5.7527e-02,  6.2746e-02],
#           [ 2.2629e-02,  1.4394e-02, -6.9959e-03,  ..., -3.2290e-02,
#             5.3415e-02,  6.0606e-02],
#           ...,
#           [-4.7036e-05,  1.4305e-02, -1.0454e-02,  ..., -5.2365e-02,
#             5.5163e-02,  7.5830e-02],
# ...
