# %%
import pandas as pd

df = pd.read_csv("./data/cv-corpus-21.0-delta-2025-03-14/en/validated.tsv", delimiter="\t")
df
# Out:
#                                              client_id  \
# 0    116398939d6be70fc5fb532924a130c0adf286ac283499...
# 1    24a4da2e8f053a45a0715849c222a40a4b0da9872efb2e...
# 2    30849595699bc853c3810a78448acede46888b4e2d0809...
# 3    42d53f34c1bc50f7a7c4ed1765a8d1ffeaf5cd441513cc...
# 4    436b9e1f9da710d74eb01209f8f269bee70e93cadf2053...
# ..                                                 ...
# 244  403c1ec9623855b620b043ca2ca76c02989e679e32ba27...
# 245  403c1ec9623855b620b043ca2ca76c02989e679e32ba27...
# 246  403c1ec9623855b620b043ca2ca76c02989e679e32ba27...
# 247  403c1ec9623855b620b043ca2ca76c02989e679e32ba27...
# 248  403c1ec9623855b620b043ca2ca76c02989e679e32ba27...
#
#                              path  \
# 0    common_voice_en_41923025.mp3
# 1    common_voice_en_42356358.mp3
# 2    common_voice_en_42165090.mp3
# 3    common_voice_en_41921729.mp3
# 4    common_voice_en_42528393.mp3
# ..                            ...
# 244  common_voice_en_42220527.mp3
# ...

# %%
df.gender.value_counts()
# Out:
# gender
# female_feminine       143
# male_masculine         42
# do_not_wish_to_say      9
# Name: count, dtype: int64

# %%
df.age.value_counts()
# Out:
# age
# twenties    126
# thirties     56
# sixties      31
# teens        14
# fourties      7
# fifties       2
# nineties      1
# Name: count, dtype: int64

# %%
df.accents.value_counts()
# Out:
# accents
# nigerian accent                                                          95
# United States English                                                    81
# Canadian English                                                         31
# British English / Received Pronunciation (RP)                             6
# United States English,Filipino                                            5
# Lithuanian,Non-native                                                     5
# England English                                                           4
# Scottish English                                                          4
# India and South Asia (India, Pakistan, Sri Lanka)                         4
# L2                                                                        3
# United States English,Southern United States English,Lightly Southern     2
# Filipino                                                                  1
# ...

# %%
from tqdm import tqdm
import shutil

clip_path = "./data/cv-corpus-21.0-delta-2025-03-14/en/clips"
output_path = "./data/cv-corpus-21.0-delta-2025-03-14/validated_clips"

for index, row in tqdm(df.iterrows()):
    clip_file = f"{clip_path}/{row['path']}"
    shutil.copyfile(clip_file, f"{output_path}/{row['path']}")
# Out:
# 249it [00:00, 792.00it/s]
